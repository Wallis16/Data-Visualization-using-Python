# %%
#NUMPY

# %%
import numpy as np

# !head Coordenadas_das_estacoes.csv
# Out:
# NOME_DA_ESTACAO,MUNICIPIO,LATITUDE,LONGITUDE
# Abreu_e_Lima,Abreu_e_Lima,-7.9281,-34.9
# Afogados_da_Ingazeira,Afogados_da_Ingazeira,-7.7503,-37.6406
# Afranio ,Afranio ,-8.5167,-41.005
# Afranio - PCD ,Afranio ,-8.5186,-41.0103
# Agrestina ,Agrestina ,-8.4578,-35.9536
# Agua Preta ,Agua Preta ,-8.7025,-35.5219
# Aguas Belas ,Aguas Belas ,-9.1292,-37.0368
# Aguas Belas (Centro) ,Aguas Belas ,-9.116,-37.118
# Alagoinha ,Alagoinha ,-8.4661,-36.7739

# %%
dtype = dict(names=('NOME','MUNICIPIO','LAT','LONG'),
            formats=('S64','S64','f','f'))

booze = np.loadtxt("Coordenadas_das_estacoes.csv", delimiter=',', dtype=dtype, skiprows=1)

booze[np.where(booze['LAT'] == -8.4661)]
# Out:
# array([(b'Alagoinha ', b'Alagoinha ', -8.4661, -36.7739)],
#       dtype=[('NOME', 'S64'), ('MUNICIPIO', 'S64'), ('LAT', '<f4'), ('LONG', '<f4')])

# %%
# !head PE_pluviometria.csv
# Out:
# Codigo,Posto,Ano,Janeiro,Fevereiro,Marco,Abril,Maio,Junho,Julho,Agosto,Setembro,Outubro,Novembro,Dezembro
# 198,Abreu e Lima,2018,122.1,55.1,221.2,517.9,159.5,136.4,135.5,32.9,59.1,13.1,51,19.9
# 290,Afogados da Ingazeira,2018,104.4,216,181,259,45,-,2,-,2,-,70.5,13
# 1,Afranio,2018,54.8,96,143.9,91.6,-,-,-,-,-,32.5,1,31.5
# 369,Afranio - PCD,2018,-,-,-,-,0.8,0.8,-,-,-,21.1,-,14.2
# 115,Agrestina,2018,36.2,97.2,89.4,168.7,78.1,84.4,48.7,15,10.1,-,11,47.9
# 80,Agua Preta,2018,136,133,207.2,323,225.1,68,90.6,29.8,26.4,1,62.8,35.7
# 78,Aguas Belas,2018,43.1,56.5,81.5,42,73.1,24.7,32.5,3.2,12.8,-,9.9,29.6
# 607,Aguas Belas - PCD,2018,52.6,81.8,59.6,54.8,96.6,31.2,36.6,3.8,11.6,-,15.6,33.8
# 140,Alagoinha,2018,19.7,86.9,41.1,161.4,59.7,16.3,19.6,1.1,4.9,3.9,11.5,64.9

# %%
dtype = dict(names=('Codigo','Posto','Ano','Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez'),
             formats=('f','S64','f','S64','S64','S64','S64','S64','S64','S64','S64','S64','S64','S64','S64'))

booze = np.loadtxt("PE_pluviometria.csv", delimiter=',', dtype=dtype, skiprows=1)

booze[np.where(booze['Codigo'] == 80)]

#We have a problem, because some data has '-' instead a value, so we can't use np.mean to get mean of data.
#However I let here np.mean using 'Codigo' data, just for ilustrate
np.mean(booze['Codigo'])
# Out:
# 225.12447

# %%
#PANDAS

# %%
import pandas as pd
import matplotlib.pyplot as plt

booze = pd.read_csv("PE_pluviometria.csv")
booze
# Out:
#      Codigo                                 Posto   Ano Janeiro Fevereiro  \
# 0       198                          Abreu e Lima  2018   122.1      55.1
# 1       290                 Afogados da Ingazeira  2018   104.4       216
# 2         1                               Afranio  2018    54.8        96
# 3       369                         Afranio - PCD  2018       -         -
# 4       115                             Agrestina  2018    36.2      97.2
# 5        80                            Agua Preta  2018     136       133
# 6        78                           Aguas Belas  2018    43.1      56.5
# 7       607                     Aguas Belas - PCD  2018    52.6      81.8
# 8       140                             Alagoinha  2018    19.7      86.9
# 9        66                               Alianca  2018    94.4     162.4
# 10      116                               Altinho  2018      81      85.2
# 11      105                               Amaraji  2018   278.5       306
# ...

# %%
booze[booze.Codigo == 140]
# Out:
#    Codigo      Posto   Ano Janeiro Fevereiro Marco  Abril  Maio Junho Julho  \
# 8     140  Alagoinha  2018    19.7      86.9  41.1  161.4  59.7  16.3  19.6
#
#   Agosto Setembro Outubro Novembro Dezembro
# 8    1.1      4.9     3.9     11.5     64.9

# %%
booze.sort_values(by='Codigo')
# Out:
#      Codigo                                 Posto   Ano Janeiro Fevereiro  \
# 2         1                               Afranio  2018    54.8        96
# 14        3                             Araripina  2018   144.5     158.4
# 154       4                             Petrolina  2018      34     162.1
# 179       6              Santa Maria da Boa Vista  2018    46.3     182.2
# 45        7                               Cabrobo  2018    29.5     184.1
# 171       8                             Salgueiro  2018    43.1     239.6
# 23        9          Belem de Sao Francisco (IPA)  2018       8       147
# 191      11                  Sao Jose do Belmonte  2018    82.5     265.5
# 199      12                   Serra Talhada (IPA)  2018    30.3     153.4
# 197      13                         Serra Talhada  2018    31.6       188
# 90       14                        Ibimirim (IPA)  2018    11.9       131
# 16       16                     Arcoverde (INMET)  2018    45.9     157.9
# ...

# %%
booze.describe()
# Out:
#            Codigo     Ano
# count  233.000000   233.0
# mean   225.124464  2018.0
# std    171.170682     0.0
# min      1.000000  2018.0
# 25%     92.000000  2018.0
# 50%    175.000000  2018.0
# 75%    353.000000  2018.0
# max    607.000000  2018.0

# %%
faves = booze.Codigo

newbooze = pd.concat((booze, pd.DataFrame({'new_column':faves})), axis=1)
newbooze
# Out:
#      Codigo                                 Posto   Ano Janeiro Fevereiro  \
# 0       198                          Abreu e Lima  2018   122.1      55.1
# 1       290                 Afogados da Ingazeira  2018   104.4       216
# 2         1                               Afranio  2018    54.8        96
# 3       369                         Afranio - PCD  2018       -         -
# 4       115                             Agrestina  2018    36.2      97.2
# 5        80                            Agua Preta  2018     136       133
# 6        78                           Aguas Belas  2018    43.1      56.5
# 7       607                     Aguas Belas - PCD  2018    52.6      81.8
# 8       140                             Alagoinha  2018    19.7      86.9
# 9        66                               Alianca  2018    94.4     162.4
# 10      116                               Altinho  2018      81      85.2
# 11      105                               Amaraji  2018   278.5       306
# ...

# %%
bt = booze.transpose()

try:
    float(bt.iloc[3])
except:
    print("ops")
    
#subset
bt.iloc[14,0:10]
# Out:
# ops
# 0    19.9
# 1      13
# 2    31.5
# 3    14.2
# 4    47.9
# 5    35.7
# 6    29.6
# 7    33.8
# 8    64.9
# 9    35.3
# Name: Dezembro, dtype: object

# %%
booze = pd.read_csv("Coordenadas_das_estacoes.csv")
booze = booze.sort_values(by='LATITUDE')
booze = booze.sort_values(by='LONGITUDE')
booze
# Out:
#                               NOME_DA_ESTACAO                  MUNICIPIO  \
# 3                              Afranio - PCD                    Afranio
# 2                                    Afranio                    Afranio
# 73                                 Dormentes                  Dormentes
# 156                          Petrolina - PCD                  Petrolina
# 178                           Santa Filomena             Santa Filomena
# 154                                Petrolina                  Petrolina
# 14                                 Araripina                  Araripina
# 155                        Petrolina (INMET)                  Petrolina
# 15                           Araripina - PCD                  Araripina
# 176                               Santa Cruz                 Santa Cruz
# 124                             Lagoa Grande               Lagoa Grande
# 219                                 Trindade                   Trindade
# ...

# %%
plt.plot(booze['LONGITUDE'], booze['LATITUDE'], label='Coordinates')

plt.legend(loc='best')
plt.xlabel('LONGITUDE')
plt.ylabel('LATITUDE')
# Out:
# Text(0, 0.5, 'LATITUDE')

# %%
#BASEMAP

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# %matplotlib inline

# 3D Orthographic projection with pretty satellite image
m = Basemap(projection='ortho', lon_0=-41.010300, lat_0=-8.51860);
m.bluemarble()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %matplotlib inline
# Set up figure size and DPI for screen demo
plt.rcParams['figure.figsize'] = (6,4)
plt.rcParams['figure.dpi'] = 150

def setup_map(m):
    m.drawcoastlines(zorder=-1)
    m.fillcontinents(color='olive',lake_color='aqua', zorder=-1)
    # draw parallels and meridians.
    m.drawmapboundary(fill_color='aqua')
    plt.gcf().set_size_inches(12,10)

# Add Terminator
import datetime
#m = Basemap(width=1.2e7,height=9e6,projection='lcc', lat_1=45.,lat_2=55,lat_0=49.5,lon_0=8.7)
m = Basemap(width=1.2e7,height=9e6,projection='lcc',lon_0=-41.010300, lat_0=-8.51860)
m.nightshade(datetime.datetime.now())
setup_map(m)

# %%
# Add parallels & Meridians
m = Basemap(width=1.2e7,height=9e6,projection='lcc', lon_0=-41.010300, lat_0=-8.51860)
m.drawmeridians(np.arange(0,360,30), labels=[1,0,0,1])
m.drawparallels(np.arange(0,90,30), labels=[0,1,1,0])
setup_map(m)

# %%
# Level of detail with resolution
m = Basemap(width=5e6,height=4e6,projection='lcc', lon_0=-41.010300, lat_0=-8.51860, resolution='h')
m.drawcountries()
setup_map(m)

# %%
# Level of detail with resolution
m = Basemap(width=5e6,height=4e6,projection='lcc', lon_0=-41.010300, lat_0=-8.51860, resolution='f')
m.drawcountries()
setup_map(m)
